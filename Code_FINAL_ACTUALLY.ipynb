# %% [markdown]
# # Iron Deficiency in Households with Children in Northern Uganda

# %%
# Loading in necessary packages
#!pip install -r requirements.txt
import numpy as np
import pandas as pd
import cfe
import matplotlib.pyplot as plt
import wbdata
from utils import get_clean_sheet, change_prices, increase_nutrient_content
# Out:
# /Users/cnicholas/src/EEP153/team_Luther_Tweetan/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.31.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.31.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Loading in necessary dataframes
import pandas as pd

InputFiles = {'Expenditures':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','Expenditures (2019-20)'),
              'Prices':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','Prices'),
              'HH Characteristics':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','HH Characteristics'),
              'FCT':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','FCT'),
              'RDI':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','RDI'),}


# Get expenditures...
expenditures = get_clean_sheet(InputFiles['Expenditures'][0],
                    sheet=InputFiles['Expenditures'][1])

if 'm' not in expenditures.columns:
    expenditures['m'] = 1

expenditures = expenditures.set_index(['i','t','m'])
expenditures.columns.name = 'j'
expenditures = expenditures.apply(lambda x: pd.to_numeric(x,errors='coerce'))
expenditures = expenditures.replace(0,np.nan)

# Get HH characteristics...
hh_charactaristics = get_clean_sheet(InputFiles['HH Characteristics'][0],
                    sheet=InputFiles['HH Characteristics'][1])

if 'm' not in hh_charactaristics.columns:
    hh_charactaristics['m'] = 1

hh_charactaristics = hh_charactaristics.set_index(['i','t','m'])
hh_charactaristics.columns.name = 'k'

hh_charactaristics = hh_charactaristics.apply(lambda x: pd.to_numeric(x,errors='coerce'))

# Get prices
prices = get_clean_sheet(InputFiles['Prices'][0],
                    sheet=InputFiles['Prices'][1])

if 'm' not in prices.columns:  # Supply "market" indicator if missing
    prices['m'] = 1

prices = prices.set_index(['t','m'])
prices.columns.name = 'j'

prices = prices.apply(lambda x: pd.to_numeric(x,errors='coerce'))
prices = prices.replace(0,np.nan)

fct = get_clean_sheet(InputFiles['FCT'][0],
                    sheet=InputFiles['FCT'][1])

#### This bit peculiar to Niger FCT #####
#fct = fct.loc[fct.Code.str.len()==6]
#fct = fct.set_index('Code')
#fct.columns = [v.replace('\n',' ') for v in fct.columns]
########################################
fct = fct.set_index('j')
fct.columns.name = 'n'

fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))

################## RDI, if available (consider using US) #####################
rdi = get_clean_sheet(InputFiles['RDI'][0],
                    sheet=InputFiles['RDI'][1])
rdi = rdi.set_index('n')
rdi.columns.name = 'k'

# Take logs of expenditures; call this y
y = np.log(expenditures)

# %% [markdown]
# ### Filtering our household characteristics dataset to include households with at least one child

# %%
hh_charactaristics = hh_charactaristics[rdi.columns.tolist()]
filtered_hh_charactaristics = hh_charactaristics[(hh_charactaristics['F 00-03']!=0) | (hh_charactaristics['M 00-03']!=0) | (hh_charactaristics['F 04-08']!=0) | (hh_charactaristics['M 04-08']!=0)]
filtered_z = filtered_hh_charactaristics.xs('2019-20',level='t',drop_level=False)
filtered_hh_rdi = filtered_hh_charactaristics@rdi.T

# Uganda data is per week, so make this a recommended WEEKLY intake:
filtered_hh_rwi = filtered_hh_rdi*7

# %% [markdown]
# ### Running a regression on the full dataset

# %%
result = cfe.Regression(y=np.log(expenditures.stack()),d=hh_charactaristics)

xhat = result.predicted_expenditures()

# Expenditures divided by prices/kg gives quantities in kgs...
qhat = (xhat.unstack('j')/prices).dropna(how='all')

# Drop missing columns
qhat = qhat.loc[:,qhat.count()>0]

use = fct.index.intersection(qhat.columns)
nutrients = qhat[use]@fct.loc[use,:]
use_nutrients = nutrients.columns.intersection(filtered_hh_rwi.columns)
nutrient_ratio = (nutrients[use_nutrients]/filtered_hh_rwi[use_nutrients]).dropna()
#ax = result.graph_beta()

# %% [markdown]
# ## Introduction:
#
# We are exploring the percentage of Uganda households with children that suffer from iron deficiency, and exploring possible solutions to combat it. We chose iron as a nutrient because a significant amount of households fail to hit the recommended daily amount as shown by the histogram below.

# %%
nutrient_ratio['Iron'].hist(bins=100)
plt.axvline(x = 1, color = 'r', label = 'axvline - full height')

# %%
# Below is the percentage of households with at least one child 0-8 in Uganda that are below recommended iron levels
# And the mean of iron ratios of all the households
percent_households_under_rdi = len(nutrient_ratio[nutrient_ratio['Iron']<1])/len(nutrient_ratio['Iron'])
print(percent_households_under_rdi)
print(nutrient_ratio['Iron'].mean())
# Out:
# 0.5530054644808743
# 1.0511811928828787

# %% [markdown]
# ## Iron content of beans and millet
#
# Beans (fresh and dry) and millet have significant amounts of iron (mg) in them, as shown by the FCT results below

# %%
fct.loc[['Beans (dry)', 'Beans (fresh)', 'Millet']]['Iron']
# Out:
# j
# Beans (dry)      30.0
# Beans (fresh)    51.0
# Millet           30.0
# Name: Iron, dtype: float64

# %% [markdown]
# However, these two products have very different elasticities:

# %%
xhat = result.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median


# Reference prices chosen from a particular time; average across place.
# These are prices per kilogram:
pbar = prices.mean()
pbar = pbar[result.beta.index] # Only use prices for goods we can estimate

#Finally, define a function to change a single price in the vector $p$:
def my_prices(p0,p=pbar,j='Millet'):
    """
    Change price of jth good to p0, holding other prices fixed.
    """
    p = p.copy()
    p.loc[j] = p0
    return p
pbar

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# %%
# %matplotlib inline
use = 'Beans'  # Good we want demand curve for

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# Demand for Beans for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Beans for household at 25% percentile
plt.plot([result.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Beans for household at 75% percentile
plt.plot([result.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of {use} Demanded")
# Out:
# Text(0.5, 0, 'Quantities of Beans Demanded')

# %%
# %matplotlib inline
use = 'Millet'  # Good we want demand curve for

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# Demand for Millet for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Millet for household at 25% percentile
plt.plot([result.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Millet for household at 75% percentile
plt.plot([result.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of {use} Demanded")
# Out:
# Text(0.5, 0, 'Quantities of Millet Demanded')

# %% [markdown]
# As shown, beans have a much more inelastic demand curve than millet at all simulated household budgets

# %% [markdown]
# ## Fortification
#
# We want to see how much iron intake would change if the iron content of beans and millet were increased through new HarvestPlus varietals. Let's create the same stats as above but with a 30% increase in the iron content of fresh and dry beans.

# %% [markdown]
# ### Unit Test for function we wrote:

# %%
# Manual unit test for increase_nutrient_content function

# We already know Iron content of Millet is 30 mg as shown above

# Will run function with 0 increase in percent to make sure it outputs correctly

test = increase_nutrient_content(fct, ['Millet'], nutrient='Iron', increase_percent=0)
# Out:
# Before update: Millet iron content =                    30.0
# After update: Millet iron content =                30.0

# %%
# It works!

# %%
# Test the function with debug statements
updated_fct = increase_nutrient_content(fct, ['Beans (dry)', 'Beans (fresh)', 'Millet'], nutrient='Iron', increase_percent=30)
# Out:
# Before update: Beans (dry) iron content =                    30.0
# After update: Beans (dry) iron content =                39.0
# Before update: Beans (fresh) iron content =                    51.0
# After update: Beans (fresh) iron content =                66.3
# Before update: Millet iron content =                    30.0
# After update: Millet iron content =                39.0

# %% [markdown]
# Creating a new histogram with the fortified beans and millet:

# %%
use = updated_fct.index.intersection(qhat.columns)
nutrients_2 = qhat[use]@updated_fct.loc[use,:]
use_nutrients2 = nutrients_2.columns.intersection(filtered_hh_rwi.columns)
nutrient_ratio_2 = (nutrients_2[use_nutrients2]/filtered_hh_rwi[use_nutrients2]).dropna()

# %%
nutrient_ratio_2['Iron'].hist(bins=100)
plt.axvline(x = 1, color = 'r', label = 'axvline - full height')

# %%
percent_households_under_rdi_updated = len(nutrient_ratio_2[nutrient_ratio_2['Iron']<1])/len(nutrient_ratio_2['Iron'])
print(percent_households_under_rdi_updated)
print(nutrient_ratio_2['Iron'].mean())
# Out:
# 0.5300546448087432
# 1.07879288665324

# %%
# Let's see the difference between the percentage of households not hitting the recommended iron intake 
# between the non-fortified items and the fortified items
print(percent_households_under_rdi - percent_households_under_rdi_updated)
# Out:
# 0.022950819672131084

# %% [markdown]
# It only changes by 2%, which is not encouraging. Why is that?  Let's look at the Gamma function, and see what kids eat

# %%
result.get_gamma()
# Out:
# k                F 00-03   M 00-03   F 04-08   M 04-08   F 09-13   M 09-13  \
# j
# Beans          -0.039565  0.022731  0.115758  0.110370  0.144533  0.121766
# Beef           -0.095906  0.019067  0.072510  0.052052  0.055077  0.040920
# Biscuits       -0.014651  0.331672 -0.075225  0.022947  0.008386 -0.086788
# Bread           0.031579 -0.012458  0.089535  0.142977 -0.015823  0.054208
# Cabbages        0.042346 -0.007181 -0.012052  0.077720  0.071831  0.043394
# Cassava         0.055481  0.040858  0.121313  0.170759  0.128214  0.221090
# Chapati        -0.017294  0.049308  0.025193  0.091275  0.105073 -0.000581
# Cooking Oil     0.002053 -0.019688  0.041639  0.014623  0.026865  0.039439
# Dodo           -0.039661  0.008196  0.033345  0.064539  0.138606  0.107345
# Eggs           -0.038116  0.095888  0.023924  0.036596  0.073488  0.005982
# Fish (dried)    0.081347  0.078233  0.027383  0.076231  0.070997  0.059813
# Fish (fresh)    0.038039  0.102356  0.091486  0.068959  0.139777  0.157318
# Goat            0.101600  0.096587  0.065495  0.010986 -0.083989 -0.035242
# Ground Nuts     0.035074  0.061081  0.038069  0.026678  0.088098  0.025377
# Maize           0.078326  0.155956  0.158631  0.090574  0.180211  0.183074
# Mangos         -0.020361  0.169549  0.047027  0.024303  0.054278  0.044737
# Matoke          0.040310  0.022035  0.047408  0.067254  0.085286  0.091444
# Milk (fresh)    0.064423  0.030690  0.043372  0.019519  0.066484  0.044560
# Millet         -0.070017 -0.056822  0.077424  0.040338  0.072827  0.137386
# Onions         -0.046989 -0.048690 -0.006045 -0.016845  0.014595  0.012175
# Oranges         0.031679  0.092629  0.079362  0.182386  0.053410  0.209045
# Other Fruits   -0.083852  0.067652  0.045308 -0.007660  0.093527  0.019439
# Other Veg.     -0.024993  0.081809  0.023049  0.062290  0.037187  0.093047
# Peas            0.099059  0.100652  0.062066 -0.017256  0.105401  0.119850
# Pork            0.027312 -0.006936  0.074116  0.045306  0.068358 -0.007511
# Rice            0.060274  0.075861  0.097003  0.144011  0.089188  0.115281
# Salt            0.052601  0.080622  0.101109  0.103431  0.067647  0.097572
# Sim Sim         0.031929  0.121789 -0.068383  0.088664  0.092428  0.084245
# Biscuits        0.341167 -0.319113  6.808312
# Bread           0.177430  0.150112  8.288905
# Cabbages        0.099014  0.088713  7.046905
# Cassava         0.168699  0.161396  8.438791
# Chapati        -0.035129  0.170069  7.643618
# Cooking Oil     0.002136  0.115287  7.263638
# Dodo            0.222994  0.220001  7.234389
# Eggs            0.166637  0.034525  7.733178
# Fish (dried)    0.240173  0.172999  8.630666
# Fish (fresh)    0.050495  0.219088  7.952461
# Goat            0.086862  0.341177  9.165589
# Ground Nuts     0.232358  0.158343  7.741816
# Maize           0.259806  0.213336  8.417581
# Mangos          0.097434  0.134827  7.685300
# Matoke          0.243545  0.222516  9.267459
# Milk (fresh)    0.234443  0.175388  8.330119
# Millet          0.254338  0.316449  7.955959
# Onions          0.031969  0.103969  6.407586
# Oranges         0.056502  0.194935  7.178515
# Other Fruits    0.259571  0.215582  7.581768
# Other Veg.      0.268400  0.186666  7.265287
# Peas            0.137842  0.134598  8.002337
# Pork            0.069305  0.162542  9.052377
# Rice            0.196220  0.229661  8.464244
# Salt            0.147015  0.105780  5.763946
# Sim Sim         0.194881  0.134498  7.926702
# Soda            0.029233  0.157969  7.937487
# Sorghum        -0.132438  0.201996  7.899802
# Sweet Bananas   0.276482  0.245700  7.767488
# Sweet Potatoes  0.365971  0.097839  8.359388
# Tea             0.209841  0.204208  5.387020
# Tomatoes        0.037596  0.137764  7.241945
# Waragi         -0.128320  0.308127  8.320895

# %% [markdown]
# Expenditures on beans and millet don't seem to increase when an additional child is added. It seems as though kids don't eat a lot of Beans or Millet.
#
# Let's imagine we created a subsidy targeting kids 0-8 of $1/week.  What percentage increase to their household's budget would that represent?

# %%
expenditures.to_csv('expenditures.csv')
hh_charactaristics.to_csv('hh.csv')

# %%
from get_subsidy_increase import get_mean_increase
expenditures.to_csv('expenditures.csv')
hh_charactaristics.to_csv('hh.csv')

subsidy = 1.0
mean_increase = get_mean_increase(subsidy)
print(f'providing ${subsidy} USD/week to households with children 0-8 would increase their food budget by {mean_increase} percent')
# Out:
# providing $1.0 USD/week to households with children 0-8 would increase their food budget by 19.327128847603745 percent

# %% [markdown]
# Let's examine the "indirect utility' as calculated by the Regression object at the current point, and with the subsidy, at current prices.

# %%
xhat = result.predicted_expenditures()
xbar = xhat.groupby(['i','t','m']).sum()
x0 = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices chosen from a particular time; average across place.
pbar = prices.xs('2019-20',level='t').mean()
pbar = pbar[result.beta.index] # Only use prices for goods we can estimate

U0 = result.indirect_utility(x0,pbar)

# now add the subsidy
multiplier = 1 + (mean_increase / 100.0)
increased_x = x0 * multiplier
U1 = result.indirect_utility(increased_x,pbar)

# %%
print(f'current mean household expenditures: {x0}')
print(f'increased household expenditures {increased_x}')
print(f'current Utility at current prices: {U0}')
print(f'increased Utility with subsidy: {U1}')

indirect_utility_percentage_increase = ((U1 / U0) - 1) * 100
print(f'indirect utility increase: {indirect_utility_percentage_increase}')
# Out:
# current mean household expenditures: 145389.92804446694
# increased household expenditures 173489.62676905945
# current Utility at current prices: 28806.69043974455
# increased Utility with subsidy: 43243.254288763914
# indirect utility increase: 50.1153156736855

# %%
ex0 = result.expenditure(U0,pbar)
ex1 = result.expenditure(U1,pbar)

compensated_variation = ex1 - ex0

print(f'compensated variation at current prices is: {compensated_variation}')
# Out:
# compensated variation at current prices is: 0.0
