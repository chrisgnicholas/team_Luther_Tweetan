# %% [markdown]
# ## Estimation Example

# %% [markdown]
# Deliverables:
#
# Notes:
# - iron-fortified millet: current baseline - 47 mg/kg, varieties get up to 77 mg/kg
# - What is FCT units (iron is mg/100g)
# - Calculate cost of subsidy (multiply amount of subsidy by amount of households, do this later)
#
# INTRO
#
# 1. Show Iron deficiency histogram - what percentage is not hitting RDI, and show mean (whole population of Uganda, households with at least 1 child (00-3, 04-08))
# 2. Show FCT showing iron content of beans and millet
# 3. Show elasticities of beans and millet
#
# BEANS
#
# 4. Simulate fortification of beans ONLY (change the iron percentage in FCT) (check out on harvest plus site the iron content and compare to fct)
# 5. Show iron deficiency histogram and compare to intro's
# 6. Change prices to simulate subsidies of fortified beans ONLY (40% subsidy)
# 7. Create iron deficiency histogram and compare to intro's
# 8. Compare 5 and 7
#
# MILLET
#
# 7. Simulate fortification of millet ONLY (change the iron percentage in FCT)
# 8. Show iron deficiency histogram and compare to intro's
# 9. Change prices to simulate subsidies of fortified millet ONLY
# 10. Create iron deficiency histogram and compare to intro's
# 11. Compare 8 and 10
#
#
# COMPARISON
#
# 10. Create overlaid histogram (beans and millet) and compare means and percentage not hitting RDI
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#
# In this document we&rsquo;ll work through a simple approach to estimating
# Constant Frisch Elasticity (CFE) demand systems.
#
# There are two prerequisites; the first is the `CFEDemands` python
# module.  You may have this already, but if not it  can be installed with a simple:

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: CFEDemands>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: gspread>=5.0.1 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (5.12.4)
# Requirement already satisfied: gspread_pandas>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: oauth2client>=4.1.3 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (4.1.3)
# Requirement already satisfied: eep153_tools>=0.11 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.12.4)
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.5.2)
# Requirement already satisfied: ConsumerDemands in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (0.4.2.dev0)
# Requirement already satisfied: pandas>=1.4.2 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: ray>=2.0.0 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.11.0)
# Requirement already satisfied: scipy>=1.7.3 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.10.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.13.5)
# Requirement already satisfied: pytest>=7.1.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (7.4.4)
# Requirement already satisfied: matplotlib>=3.5.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.7.3)
# Requirement already satisfied: numpy>=1.21.5 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: joblib>=1.1.0 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: dvc>=2.18.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.50.0)
# Requirement already satisfied: xarray>=0.20.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.3.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from gspread>=5.0.1->-r requirements.txt (line 7)) (0.4.5)
# Requirement already satisfied: google-auth>=1.12.0 in /srv/conda/lib/python3.9/site-packages (from gspread>=5.0.1->-r requirements.txt (line 7)) (2.29.0)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.9/site-packages (from gspread_pandas>=3.2.0->-r requirements.txt (line 8)) (5.0.9)
# Requirement already satisfied: six>=1.6.1 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: httplib2>=0.9.1 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (0.22.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: rsa>=3.1.4 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (4.9)
# Requirement already satisfied: packaging>=19 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (24.0)
# Requirement already satisfied: pygtrie>=2.3.2 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.17.40)
# Requirement already satisfied: networkx>=2.5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.0.8)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: gto<2,>=1.6.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: shortuuid>=0.5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.13)
# Requirement already satisfied: requests>=2.22 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: scmrepo<4,>=3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.3.1)
# Requirement already satisfied: flufl.lock<8,>=5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (7.1.1)
# Requirement already satisfied: hydra-core>=1.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: pathspec>=0.10.3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fsspec in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.3.1)
# Requirement already satisfied: funcy>=1.14 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0)
# Requirement already satisfied: pyparsing>=2.4.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: shtab<2,>=1.3.4 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: voluptuous>=0.11.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.14.2)
# Requirement already satisfied: dvc-http>=2.29.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.32.0)
# Requirement already satisfied: grandalf<1,>=0.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.8)
# Requirement already satisfied: configobj>=5.0.6 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.0.8)
# Requirement already satisfied: kombu in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.3.7)
# Requirement already satisfied: rich>=12 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (13.7.1)
# Requirement already satisfied: tabulate>=0.8.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: celery in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.4.0)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.65.0)
# Requirement already satisfied: omegaconf in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: dvc-objects in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.1.0)
# Requirement already satisfied: dvc-data<3.16,>=3.15 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.15.1)
# Requirement already satisfied: pydot>=1.2.4 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: tomlkit>=0.11.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.12.4)
# Requirement already satisfied: dvc-studio-client<1,>=0.20 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.post1)
# Requirement already satisfied: psutil>=5.8 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.9.8)
# Requirement already satisfied: attrs>=22.2.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: dulwich in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.22.1)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: distro>=1.3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: colorama>=0.3.9 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: dpath<3,>=2.1.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.1.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/lib/python3.9/site-packages (from google-auth>=1.12.0->gspread>=5.0.1->-r requirements.txt (line 7)) (5.3.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.9/site-packages (from google-auth-oauthlib>=0.4.1->gspread>=5.0.1->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (6.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.51.0)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (8.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.9.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.4.2->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.4.2->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: iniconfig in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.25.3)
# Requirement already satisfied: pyyaml in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: jsonschema in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.21.1)
# Requirement already satisfied: aiosignal in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.8)
# Requirement already satisfied: click>=7.0 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: frozenlist in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: filelock in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.13.4)
# Requirement already satisfied: patsy>=0.5.2 in /srv/conda/lib/python3.9/site-packages (from statsmodels>=0.13.2->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.5.6)
# Requirement already satisfied: dictdiffer>=0.8.1 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /srv/conda/lib/python3.9/site-packages (from dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.8.3)
# Requirement already satisfied: billiard<5.0,>=4.2.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: vine<6.0,>=5.1.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.1.0)
# Requirement already satisfied: click-repl>=0.2.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: click-didyoumean>=0.3.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.3.1)
# Requirement already satisfied: atpublic>=2.3 in /srv/conda/lib/python3.9/site-packages (from flufl.lock<8,>=5->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.9.2)
# Requirement already satisfied: typer>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: entrypoints in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: semver>=2.13.0 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /srv/conda/lib/python3.9/site-packages (from hydra-core>=1.1->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.9.3)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.17.0)
# Requirement already satisfied: appdirs in /srv/conda/lib/python3.9/site-packages (from iterative-telemetry>=0.0.7->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: typing-extensions in /srv/conda/lib/python3.9/site-packages (from kombu->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.11.0)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /srv/conda/lib/python3.9/site-packages (from kombu->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=5.0.1->-r requirements.txt (line 7)) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.17.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /srv/conda/lib/python3.9/site-packages (from ruamel.yaml>=0.17.11->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: pygit2>=1.14.0 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: gitpython>3 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.14.2)
# Requirement already satisfied: setuptools in /srv/conda/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (59.8.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: referencing>=0.28.4 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.34.0)
# Requirement already satisfied: aiohttp in /srv/conda/lib/python3.9/site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.9.3)
# Requirement already satisfied: cryptography>=39.0 in /srv/conda/lib/python3.9/site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (39.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /srv/conda/lib/python3.9/site-packages (from click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.42)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /srv/conda/lib/python3.9/site-packages (from gitpython>3->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: cffi>=1.16.0 in /srv/conda/lib/python3.9/site-packages (from pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: orjson in /srv/conda/lib/python3.9/site-packages (from sqltrie<1,>=0.11.0->dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.10.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (6.0.5)
# Requirement already satisfied: pycparser in /srv/conda/lib/python3.9/site-packages (from cffi>=1.16.0->pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /srv/conda/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: wcwidth in /srv/conda/lib/python3.9/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.2.13)

# %% [markdown]
# The second prerequisite is a dataset including detailed information on
# household expenditures and characteristics.  The structure of that
# dataset is detailed in the next section.

# %% [markdown]
# ### Data

# %% [markdown]
# Consider the case in which the data are saved in a google sheet; we&rsquo;ll
# turn data from these into `pandas` dataframes.
# There are limits on the allowable size of google sheets (5 million
# cells when I last checked), so if your dataset is larger than this you&rsquo;ll need some other
# mechanism to get your data into such dataframes.  Even in this latter
# case you&rsquo;ll want your dataframes to have a structure that matches the
# description given below.

# %% [markdown]
# #### Structure of the Spreadsheet

# %% [markdown]
# An example spreadsheet with data for Uganda can be found at
# [https://docs.google.com/spreadsheets/d/1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ/](https://docs.google.com/spreadsheets/d/1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ/)
#
# This spreadsheet consists of several worksheets, labeled &ldquo;RDI&rdquo;, &ldquo;FCT&rdquo;,
# &ldquo;Household Characteristics&rdquo;, &ldquo;Prices&rdquo;, and a series of different years of food &ldquo;Expenditures&rdquo;.
#
# Each worksheet has the initial three columns labeled &ldquo;i&rdquo;, &ldquo;t&rdquo;, and
# &ldquo;m&rdquo;; together these identify an observation uniquely.  The column &ldquo;i&rdquo;
# should include a household id; the column &ldquo;t&rdquo; should include an
# indicator for the year or period (for those of you with
# cross-sectional data these will all take a common value, e.g., 2019);
# the column &ldquo;m&rdquo; should be an indicator of &ldquo;market&rdquo;, which may be a
# region identifier, or may take a single value (e.g., &ldquo;Uganda&rdquo;).
#
# The triple (i,t,m) will serve as the index of some constructed
# dataframes.  It is important not to have **too** many different values
# for &ldquo;m&rdquo; (unless you have lots of data and RAM to play with).
#
# Beyond the first three columns, the &ldquo;Expenditures&rdquo; worksheet for a given year should
# have one column for each category of expenditures (e.g., &ldquo;Beans&rdquo;, &ldquo;Beef&rdquo;, &ldquo;Beer&rdquo;,&#x2026;).
#
# Beyond the first three columns, the &ldquo;Household Characteristics&rdquo; should
# have columns corresponding to different elements of the vector of
# observable characteristics $z$.  If the data permit, I recommend
# constructing observables that match what I have in these data:
# namely numbers of different children by age and sex, along with the
# logarithm of total household size (&ldquo;log HSize&rdquo;).

# %% [markdown]
# #### From Sheet to DataFrame to Regression Object

# %% [markdown]
# We begin by defining a dictionary that contains the spreadsheet key.
# One is provided for the Ugandan example that I wish to work
# through.

# %%
Uganda_Data = '1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ'

# %% [markdown]
# With the spreadsheet defined , grab it and define a couple of
# dataframes. (Sheets should be shared with `students@eep153.iam.gserviceaccount.com`):

# %%
import pandas as pd
import numpy as np
from eep153_tools.sheets import read_sheets

# Change 'Uganda_Data' to key of your own sheet in Sheets, above
x = read_sheets(Uganda_Data,sheet='Expenditures (2019-20)')
x.columns.name = 'j'

p = read_sheets(Uganda_Data,sheet='Prices').set_index(['t','m'])
p.columns.name = 'j'
p = p.xs('2019-20',level='t')

d = read_sheets(Uganda_Data,sheet="HH Characteristics")
d.columns.name = 'k'

# x may have duplicate columns
x = x.T.groupby('j').sum().T
x = x.replace(0,np.nan) # Replace zeros with missing

# Take logs of expenditures; call this y
y = np.log(x.set_index(['i','t','m']))

d.set_index(['i','t','m'],inplace=True)
# Out:
# /tmp/ipykernel_182/3389232646.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(0,np.nan) # Replace zeros with missing

# %% [markdown]
# This gives a dataframe of household characteristics $d$ with a simple structure.

# %%
d.head()
# Out:
# k                                                 F 00-03  F 04-08  F 09-13  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19              1.0      0.0      1.0
#                                  2019-20 Eastern      1.0      0.0      0.0
# 02dd448165ce46279ca601a02865d543 2018-19              0.0      0.0      0.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19              0.0      1.0      0.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19              0.0      1.0      1.0
#
# k                                                 F 14-18  F 19-30  F 31-50  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19              3.0      1.0      0.0
#                                  2019-20 Eastern      3.0      1.0      0.0
# 02dd448165ce46279ca601a02865d543 2018-19              0.0      1.0      0.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19              0.0      0.0      1.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19              0.0      0.0      1.0
#
# k                                                 F 51+  M 00-03  M 04-08  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19            1.0      0.0      0.0
#                                  2019-20 Eastern    1.0      0.0      0.0
# 02dd448165ce46279ca601a02865d543 2018-19            0.0      0.0      0.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19            0.0      0.0      2.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19            0.0      0.0      0.0
#
# k                                                 M 09-13  M 14-18  M 19-30  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19              1.0      0.0      0.0
#                                  2019-20 Eastern      1.0      0.0      0.0
# 02dd448165ce46279ca601a02865d543 2018-19              0.0      0.0      0.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19              0.0      0.0      0.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19              1.0      0.0      0.0
#
# k                                                 M 31-50  M 51+  log HSize
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19              0.0    0.0   2.079442
#                                  2019-20 Eastern      0.0    0.0   1.945910
# 02dd448165ce46279ca601a02865d543 2018-19              0.0    0.0   0.000000
# 037866653c7c4cb99a80f05a38cdafb2 2018-19              0.0    1.0   1.609438
# 039a11571b874a88b7a6c200469fe4f3 2018-19              1.0    0.0   1.609438

# %%
filtered_d = d[(d['F 00-03']!=0) | (d['M 00-03']!=0) | (d['F 04-08']!=0) | (d['M 04-08']!=0) | (d['F 09-13']!=0) | (d['M 09-13']!=0)]
filtered_d = filtered_d.xs('2019-20',level='t',drop_level=False)
filtered_d = filtered_d.xs('Northern',level='m',drop_level=False)
filtered_d
# Out:
# k                                                  F 00-03  F 04-08  F 09-13  \
# i                                t       m
# 110f81c0d9254505838dcaf2497d130a 2019-20 Northern      0.0      0.0      1.0
# 118e5671a1e0437baebdd563bf3e43df 2019-20 Northern      0.0      1.0      0.0
# 2302300051007                    2019-20 Northern      0.0      0.0      1.0
# 2302300080102                    2019-20 Northern      0.0      0.0      1.0
# 2302300080104                    2019-20 Northern      0.0      1.0      0.0
# ...                                                    ...      ...      ...
# _47                              2019-20 Northern      1.0      1.0      0.0
# _49                              2019-20 Northern      0.0      0.0      0.0
# _60                              2019-20 Northern      0.0      0.0      0.0
# _66                              2019-20 Northern      0.0      0.0      0.0
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern      1.0      1.0      1.0
#
# k                                                  F 14-18  F 19-30  F 31-50  \
# i                                t       m
# 110f81c0d9254505838dcaf2497d130a 2019-20 Northern      0.0      0.0      0.0
# 118e5671a1e0437baebdd563bf3e43df 2019-20 Northern      2.0      0.0      1.0
# 2302300051007                    2019-20 Northern      2.0      1.0      1.0
# 2302300080102                    2019-20 Northern      1.0      0.0      0.0
# 2302300080104                    2019-20 Northern      0.0      1.0      0.0
# ...                                                    ...      ...      ...
# _47                              2019-20 Northern      0.0      2.0      0.0
# _49                              2019-20 Northern      0.0      1.0      0.0
# _60                              2019-20 Northern      0.0      1.0      0.0
# _66                              2019-20 Northern      0.0      1.0      0.0
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern      0.0      0.0      1.0
#
# k                                                  F 51+  M 00-03  M 04-08  \
# i                                t       m
# 110f81c0d9254505838dcaf2497d130a 2019-20 Northern    1.0      0.0      2.0
# 118e5671a1e0437baebdd563bf3e43df 2019-20 Northern    0.0      1.0      0.0
# 2302300051007                    2019-20 Northern    0.0      0.0      1.0
# 2302300080102                    2019-20 Northern    1.0      0.0      0.0
# 2302300080104                    2019-20 Northern    0.0      1.0      1.0
# ...                                                  ...      ...      ...
# _47                              2019-20 Northern    0.0      0.0      2.0
# _49                              2019-20 Northern    0.0      2.0      0.0
# _60                              2019-20 Northern    0.0      2.0      0.0
# _66                              2019-20 Northern    1.0      1.0      0.0
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern    0.0      1.0      1.0
#
# k                                                  M 09-13  M 14-18  M 19-30  \
# i                                t       m
# 110f81c0d9254505838dcaf2497d130a 2019-20 Northern      2.0      1.0      0.0
# 118e5671a1e0437baebdd563bf3e43df 2019-20 Northern      1.0      0.0      0.0
# 2302300051007                    2019-20 Northern      0.0      0.0      0.0
# 2302300080102                    2019-20 Northern      0.0      0.0      0.0
# 2302300080104                    2019-20 Northern      1.0      0.0      1.0
# ...                                                    ...      ...      ...
# _47                              2019-20 Northern      0.0      0.0      1.0
# _49                              2019-20 Northern      1.0      0.0      0.0
# _60                              2019-20 Northern      0.0      0.0      0.0
# _66                              2019-20 Northern      0.0      0.0      1.0
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern      1.0      0.0      0.0
#
# k                                                  M 31-50  M 51+  log HSize
# i                                t       m
# 110f81c0d9254505838dcaf2497d130a 2019-20 Northern      0.0    1.0   2.079442
# 118e5671a1e0437baebdd563bf3e43df 2019-20 Northern      0.0    0.0   1.791759
# 2302300051007                    2019-20 Northern      0.0    1.0   1.945910
# 2302300080102                    2019-20 Northern      0.0    0.0   1.098612
# 2302300080104                    2019-20 Northern      0.0    0.0   1.791759
# ...                                                    ...    ...        ...
# _47                              2019-20 Northern      0.0    0.0   1.945910
# _49                              2019-20 Northern      1.0    0.0   1.609438
# _60                              2019-20 Northern      0.0    0.0   1.098612
# _66                              2019-20 Northern      0.0    0.0   1.386294
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern      0.0    0.0   1.945910
#
# [662 rows x 15 columns]

# %% [markdown]
# Also a dataframe of log expenditures $y$ with a similarly simple
# structure.  Note that any expenditures of zero are dropped and
# replaced with a missing value indicator.

# %%
y.head()
# Out:
# j                                                    Beans      Beef  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  8.188689       NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  6.907755  8.411833
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  7.937375       NaN
# 1013000201                       2019-20 Central       NaN       NaN
#
# j                                                     Beer  Biscuits  Bongo  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern       NaN       NaN    NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN       NaN    NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern       NaN       NaN    NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern       NaN       NaN    NaN
# 1013000201                       2019-20 Central  9.769956       NaN    NaN
#
# j                                                    Bread  Butter, etc.  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern       NaN           NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern  6.214608           NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern       NaN           NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern       NaN           NaN
# 1013000201                       2019-20 Central       NaN           NaN
#
# j                                                 Cabbages  Cake   Cassava  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  7.244228   NaN  8.699515
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN   NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern       NaN   NaN  8.294050
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern       NaN   NaN  8.070906
# 1013000201                       2019-20 Central       NaN   NaN  8.294050
#
# j                                                 ...  Sugarcane  \
# i                                t       m        ...
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  ...        NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern  ...        NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  ...        NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  ...        NaN
# 1013000201                       2019-20 Central  ...        NaN
#
# j                                                 Sweet Bananas  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern            NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern            NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern            NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern            NaN
# 1013000201                       2019-20 Central       7.600902
#
# j                                                 Sweet Potatoes       Tea  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern        8.294050  5.298317
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern             NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern             NaN       NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern        8.517193  5.298317
# 1013000201                       2019-20 Central             NaN  5.991465
#
# j                                                 Tomatoes  Waragi  Water  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  6.907755     NaN    NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN     NaN    NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  6.684612     NaN    NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  6.214608     NaN    NaN
# 1013000201                       2019-20 Central  7.649693     NaN    NaN
#
# j                                                 Wheat (flour)       Yam  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern            NaN  8.006368
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern            NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern            NaN       NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern            NaN       NaN
# 1013000201                       2019-20 Central            NaN       NaN
#
# j                                                 Yogurt
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern     NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern     NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern     NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern     NaN
# 1013000201                       2019-20 Central     NaN
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Estimation

# %% [markdown]
# Let $y_{i}^j$ be log expenditures on food $j$ by household $i$ at a particular time.  We want to estimate a regression that takes the form
# $$
#       y^j_{i} = A^j(p) + \gamma_j'd_i + \beta_j w_i + \zeta^j_i.
# $$
# So, a first step is to turn our dataframe for `y` into a series, so we can put it on the left-hand side of this regression.  Then we need to make our dataframe $d$ conform:

# %%
y = y.stack()

d = d.stack()

# Check that indices are in right places!
assert y.index.names == ['i','t','m','j']
assert d.index.names == ['i','t','m','k']

# %% [markdown]
# #### Basic Estimation

# %% [markdown]
# Just one line to set up the regression:

# %%
from cfe import Regression

result = Regression(y=y,d=d)

# %% [markdown]
# And then one line to predict expenditures and estimate most of the things we need:

# %%
result.predicted_expenditures()
# Out:
# i                                 t        m         j
# 00c9353d8ebe42faabf5919b81d7fae7  2019-20  Eastern   Beans             3734.056145
#                                                      Beef              9831.715556
#                                                      Biscuits          1312.459857
#                                                      Bread             3780.272722
#                                                      Cabbages          1250.071808
#                                                                           ...
# e07bc322c4884559b4b8ca75c945dd3e  2019-20  Northern  Sweet Bananas     2513.237637
#                                                      Sweet Potatoes    7513.732200
#                                                      Tea                207.521279
#                                                      Tomatoes          1410.956143
#                                                      Waragi            4469.686843
# Length: 94325, dtype: float64

# %% [markdown]
# Now we can compare predicted log expenditures with actual:

# %%
# %matplotlib inline
df = pd.DataFrame({'y':y,'yhat':result.get_predicted_log_expenditures()})
df.plot.scatter(x='yhat',y='y')
# Out:
# <Axes: xlabel='yhat', ylabel='y'>

# %% [markdown]
# That&rsquo;s all there is to estimation!  Note that we didn&rsquo;t estimate
# demands for all goods&#x2014;lots of goods didn&rsquo;t have enough observations,
# and were automatically dropped.

# %% [markdown]
# #### Parameters

# %% [markdown]
# ##### (Relative) Income Elasticity

# %% [markdown]
# Some of the parameters have an interesting interpretation.  First among these are the $\beta$ coefficients, which govern how *income elastic* different goods are (higher values means more elastic).  These are also called *Frisch elasticities*.
# Here we use a plot to visualize, with confidence intervals.

# %%
ax = result.graph_beta()

# %% [markdown]
# To just see the values of $\beta$:

# %%
result.get_beta()
# Out:
# j
# Beans             0.316913
# Beef              0.423841
# Biscuits          0.781522
# Bread             0.677132
# Cabbages          0.403810
# Cassava           0.142661
# Chapati           0.634176
# Cooking Oil       0.416759
# Dodo              0.369812
# Eggs              0.345383
# Fish (dried)      0.446381
# Fish (fresh)      0.886778
# Goat              0.467223
# Ground Nuts       0.426204
# Maize             0.406007
# Mangos            0.463788
# Matoke            0.443616
# Milk (fresh)      0.834115
# Millet            0.360086
# Onions            0.340940
# Oranges           0.756571
# Other Fruits      0.658992
# Other Veg.        0.585797
# Peas              0.277380
# Pork              0.422006
# Rice              0.531964
# Salt              0.145142
# Sim Sim           0.563487
# Soda              0.586076
# Sorghum           0.686320
# Sweet Bananas     0.591652
# Sweet Potatoes    0.325598
# Tea               0.421568
# Tomatoes          0.488395
# Waragi            0.401824
# Name: beta, dtype: float64

# %% [markdown]
# ##### Demand and Household Composition

# %% [markdown]
# We&rsquo;re particularly interested in the effects of household composition on demand.  These are captured by the $\gamma_j$ parameters in the regression.

# %%
result.get_gamma()
# Out:
# k                F 00-03   F 04-08   F 09-13   F 14-18   F 19-30   F 31-50  \
# j
# Beans          -0.129845  0.024727  0.064567 -0.028448 -0.002598  0.029310
# Beef           -0.121810  0.046408  0.033906  0.022340  0.084701  0.093669
# Biscuits       -0.068814 -0.131646 -0.041326  0.101954 -0.122081  0.295563
# Bread          -0.015413  0.046979 -0.053303  0.016995  0.054328  0.073295
# Cabbages        0.000047 -0.052952  0.034075  0.024258 -0.010929  0.031573
# Cassava         0.024785  0.087112  0.099496  0.046304  0.021227  0.049439
# Chapati        -0.060105 -0.020808  0.063681  0.090755 -0.024146  0.013664
# Cooking Oil    -0.088183 -0.049166 -0.050817  0.017481  0.005940 -0.005681
# Dodo           -0.068655  0.003535  0.112343  0.053806  0.044161  0.075993
# Eggs           -0.105953 -0.048813  0.019172 -0.039684  0.033600 -0.005183
# Fish (dried)    0.046656 -0.007218  0.040495  0.008603 -0.004083  0.033960
# Fish (fresh)    0.024146  0.076684  0.126765  0.053754  0.065049  0.053777
# Goat           -0.003827 -0.050402 -0.200800  0.039682 -0.100133  0.075203
# Ground Nuts     0.013237  0.015216  0.068062  0.040570  0.074938  0.091543
# Maize          -0.021131  0.057953  0.096844  0.097528 -0.010593 -0.022914
# Mangos         -0.061576  0.004513  0.017853  0.062891  0.076866  0.004491
# Matoke         -0.035113 -0.032396  0.018301  0.000948 -0.062374  0.078486
# Milk (fresh)    0.025052  0.005336  0.034501  0.037748  0.057253  0.148313
# Millet         -0.141622  0.004160  0.019282 -0.021144  0.093478  0.090660
# Onions         -0.071736 -0.031344 -0.007109  0.002546  0.084256 -0.018113
# Oranges         0.031446  0.079108  0.053201  0.055743  0.339324  0.120602
# Other Fruits   -0.132696 -0.002710  0.052436 -0.005487  0.017435  0.126434
# Other Veg.     -0.068586 -0.024274 -0.002683 -0.025444  0.044153  0.112520
# Peas           -0.040790 -0.094772 -0.015547 -0.018121 -0.125731  0.044672
# Pork           -0.033656  0.014086  0.023963 -0.139544  0.101726  0.073433
# Rice            0.006396  0.043405  0.043743  0.072528  0.023635  0.083692
# Salt           -0.041373  0.005510 -0.015191 -0.037283 -0.015544  0.032865
# Sim Sim        -0.030669 -0.135316  0.040586 -0.009371  0.050600 -0.010580
# Soda           -0.064028 -0.131735  0.022161  0.057778  0.066158  0.065022
# Sorghum        -0.019363 -0.078712  0.050082 -0.002172 -0.009680 -0.034687
# Sweet Bananas  -0.052151 -0.013603 -0.076310 -0.063958  0.033555  0.077992
# Sweet Potatoes  0.098161  0.089491  0.194222  0.064835  0.005813  0.099382
# Tea            -0.042382 -0.035185  0.013232  0.022740  0.065259  0.130721
# Tomatoes       -0.041588 -0.030377 -0.030979 -0.000128  0.048132  0.027279
# Waragi         -0.343352  0.045994 -0.196042 -0.104741 -0.104941 -0.171669
#
# k                  F 51+   M 00-03   M 04-08   M 09-13   M 14-18   M 19-30  \
# j
# Beans           0.084417 -0.071322  0.020194  0.036715  0.049218  0.042955
# Beef            0.222188 -0.008614  0.026050  0.016648  0.055342  0.080857
# Biscuits        0.287443  0.270660 -0.033024 -0.136711 -0.181973 -0.019032
# Bread           0.134078 -0.061955  0.100468  0.014863  0.043759  0.054900
# Cabbages        0.057126 -0.049127  0.035070  0.004137  0.052812  0.084709
# Cassava         0.138227  0.008328  0.137877  0.190429  0.158452  0.067733
# Chapati        -0.073183  0.000267  0.047077 -0.045219 -0.043024  0.076034
# Cooking Oil    -0.081625 -0.112399 -0.077558 -0.039460 -0.007269 -0.042908
# Dodo            0.195738 -0.022117  0.035598  0.080625  0.009036  0.032212
# Eggs            0.098584  0.026998 -0.031245 -0.056543  0.002635 -0.032299
# Fish (dried)    0.204012  0.039705  0.040072  0.025001 -0.074135  0.066381
# Fish (fresh)    0.037531  0.087181  0.054395  0.144390  0.035447  0.059293
# Goat            0.007360 -0.006511 -0.096499 -0.154284 -0.024807  0.003631
# Ground Nuts     0.212355  0.037590  0.003487  0.005814  0.046110  0.054597
# Maize           0.165180  0.052915 -0.007556  0.093869  0.103813  0.046180
# Mangos          0.062067  0.129027 -0.020133  0.007101  0.062352 -0.030811
# Matoke          0.166959 -0.061651 -0.010736  0.020587  0.016185  0.067388
# Milk (fresh)    0.200898 -0.014421 -0.018812  0.009104 -0.015815  0.064984
# Millet          0.187800 -0.133507 -0.026901  0.071256  0.014302 -0.031229
# Onions          0.008946 -0.075256 -0.041738 -0.010124 -0.019404  0.012160
# Oranges         0.056272  0.092388  0.182142  0.208820  0.187388  0.063023
# Other Fruits    0.206581  0.017880 -0.056318 -0.022153  0.024694  0.044509
# Other Veg.      0.228836  0.034050  0.015050  0.048114  0.002747  0.033640
# Peas            0.028875 -0.060701 -0.148844 -0.015911  0.029012 -0.143846
# Pork            0.018390 -0.058333 -0.008243 -0.052288 -0.058001  0.026973
# Rice            0.142684  0.018691  0.086074  0.068868  0.042560  0.080745
# Salt            0.059353 -0.018579  0.008263  0.010975  0.007117 -0.009195
# Sim Sim         0.142336  0.056733  0.025250  0.020941  0.046041  0.087579
# Soda            0.037868  0.037801 -0.049805  0.110753  0.012316  0.079333
# Sorghum        -0.181918 -0.114714 -0.040236  0.074912 -0.033217  0.026380
# Sweet Bananas   0.224438  0.128711  0.056851  0.006153  0.073467  0.045048
# Sweet Potatoes  0.340967  0.109800  0.114679  0.174715  0.115915  0.060316
# Tea             0.176237 -0.080094 -0.017011  0.016910 -0.018131  0.020682
# Tomatoes       -0.014251 -0.075214 -0.023519 -0.027247 -0.044792 -0.002956
# Waragi         -0.255223  0.067177 -0.158311 -0.166235 -0.132163 -0.053405
#
# k                M 31-50     M 51+  log HSize  Constant
# j
# Beans           0.011466  0.107460   0.426698  8.409504
# Beef            0.196879  0.148855   0.122587  9.262532
# Biscuits       -0.115969 -0.374188   0.279835  6.792856
# Bread           0.172740  0.106329   0.212862  8.285099
# Cabbages        0.018162  0.054391   0.203897  7.044567
# Cassava         0.103726  0.134321   0.157361  8.437182
# Chapati         0.138217  0.134401   0.209899  7.644030
# Cooking Oil    -0.006277  0.036738   0.419226  7.262257
# Dodo            0.084695  0.194343   0.140041  7.233421
# Eggs            0.055478 -0.025709   0.309056  7.730907
# Fish (dried)    0.064574  0.142760   0.172011  8.630962
# Fish (fresh)    0.171567  0.207033   0.069131  7.951865
# Goat            0.089071  0.221986   0.531004  9.160922
# Ground Nuts     0.111010  0.137234   0.108330  7.741600
# Maize           0.044127  0.138631   0.462311  8.415360
# Mangos          0.075669  0.106466   0.202535  7.684994
# Matoke          0.158698  0.145267   0.363288  9.267410
# Milk (fresh)    0.069364  0.136029   0.189380  8.328761
# Millet          0.153994  0.237257   0.325276  7.951785
# Onions          0.131983  0.082035   0.116020  6.407458
# Oranges         0.024345  0.194713   0.001166  7.178517
# Other Fruits    0.231017  0.175866   0.221067  7.579703
# Other Veg.      0.081002  0.142732   0.218348  7.263056
# Peas           -0.141362 -0.024874   0.638375  7.986032
# Pork            0.080138  0.110900   0.243813  9.049802
# Rice            0.063892  0.177189   0.253933  8.462596
# Salt           -0.006319  0.023656   0.439357  5.763618
# Sim Sim         0.193124  0.066712   0.280677  7.920279
# Soda            0.197485  0.166200  -0.039856  7.937324
# Sorghum        -0.168734  0.118833   0.370152  7.894543
# Sweet Bananas   0.141334  0.176413   0.300664  7.765022
# Sweet Potatoes  0.025699  0.069652   0.145980  8.358587
# Tea             0.143988  0.170532   0.168847  5.385922
# Tomatoes        0.074617  0.091042   0.252019  7.241197
# Waragi          0.094746  0.221683   0.475116  8.328901

# %% [markdown]
# ##### Welfare

# %% [markdown]
# Another import quantity we estimate is $w_i$.  This is a welfare measure for the household.  Here&rsquo;s a histogram:

# %%
ax = result.get_w().plot.hist(bins=100,density=True)
result.get_w().plot.kde(ax=ax)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #### Saving Result

# %% [markdown]
# You can save the estimated result, using something like

# %%
result.to_pickle('uganda_estimates.rgsn')

# %%
result.to_pickle('../Project3/uganda_estimates.rgsn')

# %% [markdown]
# You can subsequently load this using

# %%
import cfe
result = cfe.regression.read_pickle('uganda_estimates.rgsn')

# %% [markdown]
# #### Demand and Utility

# %% [markdown]
# Having estimated the demand system, we can examine the implied demand curves.

# %% [markdown]
# ##### Budgets

# %% [markdown]
# Get food budget for all households, then find median budget:

# %%
import numpy as np

xhat = result.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# %% [markdown]
# ##### Reference Prices

# %% [markdown]
# Choose reference prices.  Here we&rsquo;ll choose a particular year, and average prices across markets.  If you wanted to focus on particular market you&rsquo;d do this differently.

# %%
# Reference prices chosen from a particular time; average across place.
# These are prices per kilogram:
pbar = p.mean()
pbar = pbar[result.beta.index] # Only use prices for goods we can estimate

#Finally, define a function to change a single price in the vector $p$:
def my_prices(p0,p=pbar,j='Millet'):
    """
    Change price of jth good to p0, holding other prices fixed.
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %% [markdown]
# ##### Demand as a function of prices

# %% [markdown]
# Let&rsquo;s take a look at demand schedules for households with different budgets.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

use = 'Peas'  # Good we want demand curve for

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# Demand for Millet for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Millet for household at 25% percentile
plt.plot([result.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Millet for household at 75% percentile
plt.plot([result.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of {use} Demanded")
# Out:
# Text(0.5, 0, 'Quantities of Peas Demanded')

# %% [markdown]
# ##### Engel Curves

# %% [markdown]
# Engel curves trace out how demand changes with budget:

# %%
fig,ax = plt.subplots()

ax.plot(np.log(scale*xref),[result.expenditures(s*xref,pbar)/(s*xref) for s in scale])
ax.set_xlabel(f'log budget (relative to base of {xref:.0f}')
ax.set_ylabel(f'Expenditure share')
ax.set_title('Engel Curves')
# Out:
# Text(0.5, 1.0, 'Engel Curves')

# %% [markdown]
# ##### Indirect Utility

# %% [markdown]
# We can also describe an indirect utility function that corresponds to these demands:

# %%
fig,ax = plt.subplots()

ax.plot(scale*xref,[result.indirect_utility(s*xref,pbar) for s in scale])
ax.set_xlabel(f'Indirect Utility (Budget relative to base of {xref:.0f}')
ax.set_ylabel(f'Utility')
ax.set_title('Indirect Utility Function')
# Out:
# Text(0.5, 1.0, 'Indirect Utility Function')
